# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
ab=pd.read_csv('Netflix_Userbase.csv')

# %%
ab.head(30)
# Out:
#     User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0         1             Basic               10  15-01-22          10-06-23
# 1         2           Premium               15  05-09-21          22-06-23
# 2         3          Standard               12  28-02-23          27-06-23
# 3         4          Standard               12  10-07-22          26-06-23
# 4         5             Basic               10  01-05-23          28-06-23
# 5         6           Premium               15  18-03-22          27-06-23
# 6         7          Standard               12  09-12-21          25-06-23
# 7         8             Basic               10  02-04-23          24-06-23
# 8         9          Standard               12  20-10-22          23-06-23
# 9        10           Premium               15  07-01-23          22-06-23
# 10       11             Basic               10  16-05-22          22-06-23
# 11       12           Premium               15  23-03-23          28-06-23
# 12       13          Standard               12  30-11-21          27-06-23
# 13       14             Basic               10  01-08-22          26-06-23
# 14       15          Standard               12  09-05-23          28-06-23
# 15       16           Premium               15  07-04-22          27-06-23
# 16       17             Basic               10  24-01-22          25-06-23
# 17       18          Standard               12  18-10-21          24-06-23
# 18       19           Premium               15  15-02-23          23-06-23
# 19       20             Basic               10  27-05-23          22-06-23
# 20       21           Premium               15  10-06-23          22-06-23
# 21       22             Basic               10  22-07-22          28-06-23
# 22       23          Standard               12  05-12-21          27-06-23
# 23       24          Standard               12  03-04-22          26-06-23
# 24       25             Basic               10  14-03-23          28-06-23
# 25       26           Premium               15  12-01-22          27-06-23
# 26       27             Basic               10  29-08-22          25-06-23
# 27       28          Standard               12  27-09-21          24-06-23
# 28       29           Premium               15  19-12-22          23-06-23
# 29       30             Basic               10  17-05-23          22-06-23
#
#            Country  Age  Gender      Device Plan Duration
# 0    United States   28    Male  Smartphone       1 Month
# 1           Canada   35  Female      Tablet       1 Month
# 2   United Kingdom   42    Male    Smart TV       1 Month
# 3        Australia   51  Female      Laptop       1 Month
# 4          Germany   33    Male  Smartphone       1 Month
# 5           France   29  Female    Smart TV       1 Month
# 6           Brazil   46    Male      Tablet       1 Month
# 7           Mexico   39  Female      Laptop       1 Month
# 8            Spain   37    Male  Smartphone       1 Month
# 9            Italy   44  Female    Smart TV       1 Month
# 10   United States   31  Female  Smartphone       1 Month
# 11          Canada   45    Male      Tablet       1 Month
# 12  United Kingdom   48  Female      Laptop       1 Month
# 13       Australia   27    Male  Smartphone       1 Month
# 14         Germany   38  Female    Smart TV       1 Month
# 15          France   36    Male      Tablet       1 Month
# 16          Brazil   30  Female      Laptop       1 Month
# 17          Mexico   43    Male  Smartphone       1 Month
# 18           Spain   32  Female    Smart TV       1 Month
# 19           Italy   41    Male      Tablet       1 Month
# 20   United States   26  Female      Laptop       1 Month
# 21          Canada   34    Male  Smartphone       1 Month
# 22  United Kingdom   49  Female    Smart TV       1 Month
# 23       Australia   31    Male      Tablet       1 Month
# 24         Germany   40  Female      Laptop       1 Month
# 25          France   29    Male  Smartphone       1 Month
# 26          Brazil   47  Female    Smart TV       1 Month
# 27          Mexico   33    Male      Tablet       1 Month
# 28           Spain   36  Female      Laptop       1 Month
# 29           Italy   42    Male  Smartphone       1 Month

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
ab.isnull().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
ab['Plan Duration'] = ab['Plan Duration'].str.extract('(\d+)').astype(float)
ab = pd.get_dummies(ab, columns=['Gender', 'Subscription Type'], drop_first=True)

# %%
X_revenue = ab[['Age', 'Plan Duration', 'Subscription Type_Standard']]
X_feedback = ab[['Age', 'Plan Duration', 'Subscription Type_Standard', 'Gender_Male']]

# %%
ab.describe()
# Out:
#           User ID  Monthly Revenue          Age  Plan Duration  Gender_Male  \
# count  2500.00000      2500.000000  2500.000000         2500.0  2500.000000
# mean   1250.50000        12.508400    38.795600            1.0     0.497200
# std     721.83216         1.686851     7.171778            0.0     0.500092
# min       1.00000        10.000000    26.000000            1.0     0.000000
# 25%     625.75000        11.000000    32.000000            1.0     0.000000
# 50%    1250.50000        12.000000    39.000000            1.0     0.000000
# 75%    1875.25000        14.000000    45.000000            1.0     1.000000
# max    2500.00000        15.000000    51.000000            1.0     1.000000
#
#        Subscription Type_Premium  Subscription Type_Standard
# count                 2500.00000                 2500.000000
# mean                     0.29320                    0.307200
# std                      0.45532                    0.461425
# min                      0.00000                    0.000000
# 25%                      0.00000                    0.000000
# 50%                      0.00000                    0.000000
# 75%                      1.00000                    1.000000
# max                      1.00000                    1.000000

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(ab['Age'], ab['Plan Duration'], c=ab['Subscription Type_Standard'],
cmap='Pastel2')
plt.title('Age vs Plan Duration')
plt.xlabel('Age')
plt.ylabel('Plan Duration')
# Out:
# Text(0, 0.5, 'Plan Duration')

# %%
plt.subplot(1, 1, 1)
device_counts = ab['Device'].value_counts()
device_counts.plot(kind='bar', color='lightcoral')
plt.title('Device Distribution')
plt.xlabel('Device')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.subplot(1, 1, 1)
plt.hist(ab['Age'], bins=20, color='green', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
X_train_rev, X_test_rev, y_train_rev, y_test_rev = train_test_split(X_revenue, ab['Monthly Revenue'], test_size=0.2, random_state=42)

# %%
linear_reg = LinearRegression()
linear_reg.fit(X_train_rev, y_train_rev)
# Out:
# LinearRegression()

# %%
y_pred_rev = linear_reg.predict(X_test_rev)
r2_rev = r2_score(y_test_rev, y_pred_rev)
rmse_rev = np.sqrt(mean_squared_error(y_test_rev, y_pred_rev))
print("Linear Regression Model Metrics:")
print(f"R-squared: {r2_rev}")
print(f"RMSE: {rmse_rev}")
# Out:
# Linear Regression Model Metrics:
# R-squared: -0.007993277926992004
# RMSE: 1.668602613142419

# %%
ab['Feedback'] = np.where(ab['Monthly Revenue'] > ab['Monthly Revenue'].median(), 1, 0)
X_train_fb, X_test_fb, y_train_fb, y_test_fb = train_test_split(X_feedback, ab['Feedback'], test_size=0.2, random_state=42)

# %%
logistic_reg = LogisticRegression()
logistic_reg.fit(X_train_fb, y_train_fb)
# Out:
# LogisticRegression()

# %%
y_pred_fb = logistic_reg.predict(X_test_fb)
accuracy_fb = accuracy_score(y_test_fb, y_pred_fb)
precision_fb = precision_score(y_test_fb, y_pred_fb)
recall_fb = recall_score(y_test_fb, y_pred_fb)
f1_fb = f1_score(y_test_fb, y_pred_fb)
conf_matrix_fb = confusion_matrix(y_test_fb, y_pred_fb)
print("\nLogistic Regression Model Metrics:")
print(f"Accuracy: {accuracy_fb}")
print(f"Precision: {precision_fb}")
print(f"Recall: {recall_fb}")
print(f"F1 Score: {f1_fb}")
print("Confusion Matrix:")
print(conf_matrix_fb)
# Out:
# Logistic Regression Model Metrics:
# Accuracy: 0.5
# Precision: 0.4887459807073955
# Recall: 0.6255144032921811
# F1 Score: 0.5487364620938628
# Confusion Matrix:
# [[ 98 159]
#  [ 91 152]]

# %%
feature_importance = pd.DataFrame({'Feature': X_revenue.columns, 'Coefficient': linear_reg.coef_})
print("\nFeature Importance for Linear Regression Model:")
print(feature_importance)
# Out:
# Feature Importance for Linear Regression Model:
#                       Feature  Coefficient
# 0                         Age    -0.008295
# 1               Plan Duration     0.000000
# 2  Subscription Type_Standard    -0.087212
